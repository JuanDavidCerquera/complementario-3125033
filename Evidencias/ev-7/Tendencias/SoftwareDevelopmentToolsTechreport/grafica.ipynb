# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Intentar leer el archivo CSV con diferentes codificaciones
df = pd.read_csv('SoftwareDeveloment.csv', sep=';')
df.head()
# Out:
#                  Categoría  Porcentaje
# 0  Enterprise Applications        84.7
# 1      Business Automation        53.9
# 2               E-Commerce        38.5
# 3                 Big Data        30.8
# 4                      CRM        15.4

# %%
# Crear el gráfico
plt.figure(figsize=(10, 6))
plt.bar(df['Categoría'], df['Porcentaje'], color='skyblue')

# Configurar el gráfico
plt.xlabel('Categoría')
plt.ylabel('Porcentaje')
plt.title('Porcentaje de dificultades por Categoría')
plt.xticks(rotation=45)
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
# Asignar valores numéricos a los lenguajes para calcular la línea de tendencia
df['nombre_numerico'] = range(len(df))  # Crear índices numéricos para los lenguajes
y= df['nombre_numerico']
x = df['Porcentaje']


# Ajustar los datos a un polinomio de grado 2 (curva)
coeficientes = np.polyfit(x, y, 2)  # Grado 2
polinomio = np.poly1d(coeficientes)

# Generar valores de la línea de tendencia
x_linea = np.linspace(x.min(), x.max(), 100)  # Valores de X para la curva
y_linea = polinomio(x_linea)  # Valores de Y según el polinomio


plt.figure(figsize=(10, 13))
plt.scatter(x, y, marker='o', color='blue', label="Dificultad de categoria")
plt.plot(x_linea, y_linea, color='red', label="Línea de tendencia (curva)")  # Línea de tendencia curva
# Configurar el eje X con las etiquetas originales
plt.yticks(ticks=df['nombre_numerico'], labels=df['Categoría'], rotation=45, ha='right')


plt.title("Porcentaje de dificultades por Categoría", fontsize=16)
plt.xlabel("Porcentaje de dificultades encontradas (%)", fontsize=12)
plt.ylabel("Lenguaje", fontsize=12)

plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()

plt.show()
